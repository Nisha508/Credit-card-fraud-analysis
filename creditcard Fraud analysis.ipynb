# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
pip install -U imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\hp\anaconda3\lib\site-packages (0.10.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: scipy>=1.3.2 in c:\users\hp\anaconda3\lib\site-packages (from imbalanced-learn) (1.7.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\hp\anaconda3\lib\site-packages (from imbalanced-learn) (1.20.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\hp\anaconda3\lib\site-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\hp\anaconda3\lib\site-packages (from imbalanced-learn) (1.2.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from imbalanced-learn) (2.2.0)

# %%
#Loading the data from a csv file using pandas
#providing link of source file location
data=pd.read_csv("D:\panda\creditcard fraud analysis\creditcard.csv")

# %% [markdown]
# # display top 5 rows of dataset

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
pd.options.display.max_columns= None

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# 0  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307
# 1  0.635558  0.463917 -0.114805 -0.183361 -0.145783 -0.069083 -0.225775
# 2  2.345865 -2.890083  1.109969 -0.121359 -2.261857  0.524980  0.247998
# 3 -0.631418 -1.059647 -0.684093  1.965775 -1.232622 -0.208038 -0.108300
# 4  0.175121 -0.451449 -0.237033 -0.038195  0.803487  0.408542 -0.009431
#
#         V22       V23       V24       V25       V26       V27       V28  \
# 0  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
# 1 -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724
# 2  0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752
# 3  0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458
# 4  0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153
#
#    Amount  Class
# 0  149.62      0
# 1    2.69      0
# 2  378.66      0
# 3  123.50      0
# 4   69.99      0

# %% [markdown]
# # display last 5 rows of dataset

# %%
data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9       V10       V11       V12  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  4.356170 -1.593105  2.711941
# 284803  1.058415  0.024330  0.294869  0.584800 -0.975926 -0.150189  0.915802
# 284804  3.031260 -0.296827  0.708417  0.432454 -0.484782  0.411614  0.063119
# 284805  0.623708 -0.686180  0.679145  0.392087 -0.399126 -1.933849 -0.962886
# 284806 -0.649617  1.577006 -0.414650  0.486180 -0.915427 -1.040458 -0.031513
#
#              V13       V14       V15       V16       V17       V18       V19  \
# 284802 -0.689256  4.626942 -0.924459  1.107641  1.991691  0.510632 -0.682920
# 284803  1.214756 -0.675143  1.164931 -0.711757 -0.025693 -1.221179 -1.545556
# 284804 -0.183699 -0.510602  1.329284  0.140716  0.313502  0.395652 -0.577252
# 284805 -1.042082  0.449624  1.962563 -0.608577  0.509928  1.113981  2.897849
# 284806 -0.188093 -0.084316  0.041333 -0.302620 -0.660377  0.167430 -0.256117
#
#              V20       V21       V22       V23       V24       V25       V26  \
# 284802  1.475829  0.213454  0.111864  1.014480 -0.509348  1.436807  0.250034
# 284803  0.059616  0.214205  0.924384  0.012463 -1.016226 -0.606624 -0.395255
# 284804  0.001396  0.232045  0.578229 -0.037501  0.640134  0.265745 -0.087371
# 284805  0.127434  0.265245  0.800049 -0.163298  0.123205 -0.569159  0.546668
# 284806  0.382948  0.261057  0.643078  0.376777  0.008797 -0.473649 -0.818267
#
#              V27       V28  Amount  Class
# 284802  0.943651  0.823731    0.77      0
# 284803  0.068472 -0.053527   24.79      0
# 284804  0.004455 -0.026561   67.88      0
# 284805  0.108821  0.104533   10.00      0
# 284806 -0.002415  0.013649  217.00      0

# %% [markdown]
# # Find the shape of dataset

# %%
data.shape
# Out:
# (284807, 31)

# %%
print("Number of rows:",data.shape[0])
print("Number of columns:",data.shape[1])
# Out:
# Number of rows: 284807
# Number of columns: 31

# %%
data.describe()
# Out:
#                   V1             V2             V3             V4  \
# count  275663.000000  275663.000000  275663.000000  275663.000000
# mean       -0.037460      -0.002430       0.025520      -0.004359
# std         1.952522       1.667260       1.507538       1.424323
# min       -56.407510     -72.715728     -48.325589      -5.683171
# 25%        -0.941105      -0.614040      -0.843168      -0.862847
# 50%        -0.059659       0.070249       0.200736      -0.035098
# 75%         1.294471       0.819067       1.048461       0.753943
# max         2.454930      22.057729       9.382558      16.875344
#
#                   V5             V6             V7             V8  \
# count  275663.000000  275663.000000  275663.000000  275663.000000
# mean       -0.010660      -0.014206       0.008586      -0.005698
# std         1.378117       1.313213       1.240348       1.191596
# min      -113.743307     -26.160506     -43.557242     -73.216718
# 25%        -0.700192      -0.765861      -0.552047      -0.209618
# 50%        -0.060556      -0.270931       0.044848       0.022980
# 75%         0.604521       0.387704       0.583885       0.322319
# max        34.801666      73.301626     120.589494      20.007208
#
#                   V9            V10            V11            V12  \
# count  275663.000000  275663.000000  275663.000000  275663.000000
# mean       -0.012363       0.003114      -0.007174      -0.005347
# std         1.100108       1.087025       1.020571       0.998661
# min       -13.434066     -24.588262      -4.797473     -18.683715
# 25%        -0.659904      -0.538968      -0.772693      -0.413717
# 50%        -0.064724      -0.091752      -0.039469       0.133349
# 75%         0.593098       0.470702       0.734969       0.614670
# max        15.594995      23.745136      12.018913       7.848392
#
#                  V13            V14            V15            V16  \
# count  275663.000000  275663.000000  275663.000000  275663.000000
# mean        0.000539       0.000681      -0.010315      -0.004319
# std         0.999660       0.952571       0.917772       0.880320
# min        -5.791881     -19.214325      -4.498945     -14.129855
# 25%        -0.654360      -0.425932      -0.596079      -0.477642
# 50%        -0.011557       0.049552       0.036145       0.061670
# 75%         0.668570       0.492169       0.638997       0.524709
# max         7.126883      10.526766       8.877742      17.315112
#
#                  V17            V18            V19            V20  \
# count  275663.000000  275663.000000  275663.000000  275663.000000
# mean        0.000479       0.003874       0.000511       0.003407
# std         0.844821       0.841638       0.820520       0.779950
# min       -25.162799      -9.498746      -7.213527     -54.497720
# 25%        -0.482600      -0.498396      -0.464409      -0.212027
# 50%        -0.063489       0.001392       0.001119      -0.058053
# 75%         0.401407       0.507708       0.465782       0.139803
# max         9.253526       5.041069       5.591971      39.420904
#
#                  V21            V22            V23            V24  \
# count  275663.000000  275663.000000  275663.000000  275663.000000
# mean        0.002579       0.005827      -0.001941      -0.006868
# std         0.733089       0.726378       0.631451       0.605550
# min       -34.830382     -10.933144     -44.807735      -2.836627
# 25%        -0.225021      -0.532173      -0.165440      -0.361062
# 50%        -0.025637       0.013397      -0.013655       0.037569
# 75%         0.189118       0.534272       0.145482       0.432931
# max        27.202839      10.503090      22.528412       4.584549
#
#                  V25            V26            V27            V28  \
# count  275663.000000  275663.000000  275663.000000  275663.000000
# mean       -0.004812      -0.000240       0.001921       0.000904
# std         0.524175       0.484139       0.401271       0.332649
# min       -10.295397      -2.604551     -22.565679     -15.430084
# 25%        -0.323597      -0.328290      -0.071729      -0.052654
# 50%         0.009909      -0.056667       0.002615       0.011788
# 75%         0.347151       0.244196       0.094730       0.081355
# max         7.519589       3.517346      31.612198      33.847808
#
#               Amount          Class
# count  275663.000000  275663.000000
# mean        0.008911       0.001716
# std         1.012371       0.041388
# min        -0.353229       0.000000
# 25%        -0.328041       0.000000
# 50%        -0.258315       0.000000
# 75%        -0.033742       0.000000
# max       102.362243       1.000000

# %% [markdown]
# # get  information about dataset like number of rows. number of columns,datatypes of each column and memory requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %% [markdown]
# # check the null values in dataset

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
data["Amount"]=sc.fit_transform(pd.DataFrame(data["Amount"]))

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# 0  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307
# 1  0.635558  0.463917 -0.114805 -0.183361 -0.145783 -0.069083 -0.225775
# 2  2.345865 -2.890083  1.109969 -0.121359 -2.261857  0.524980  0.247998
# 3 -0.631418 -1.059647 -0.684093  1.965775 -1.232622 -0.208038 -0.108300
# 4  0.175121 -0.451449 -0.237033 -0.038195  0.803487  0.408542 -0.009431
#
#         V22       V23       V24       V25       V26       V27       V28  \
# 0  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
# 1 -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724
# 2  0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752
# 3  0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458
# 4  0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153
#
#      Amount  Class
# 0  0.244964      0
# 1 -0.342475      0
# 2  1.160686      0
# 3  0.140534      0
# 4 -0.073403      0

# %%
data=data.drop(["Time"],axis=1)

# %%
data
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10       V11       V12       V13  \
# 0       0.239599  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390
# 1      -0.078803  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095
# 2       0.791461  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293
# 3       0.237609  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757
# 4       0.592941 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802 -4.918215  7.305334  1.914428  4.356170 -1.593105  2.711941 -0.689256
# 284803  0.024330  0.294869  0.584800 -0.975926 -0.150189  0.915802  1.214756
# 284804 -0.296827  0.708417  0.432454 -0.484782  0.411614  0.063119 -0.183699
# 284805 -0.686180  0.679145  0.392087 -0.399126 -1.933849 -0.962886 -1.042082
# 284806  1.577006 -0.414650  0.486180 -0.915427 -1.040458 -0.031513 -0.188093
#
#              V14       V15       V16       V17       V18       V19       V20  \
# 0      -0.311169  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412
# 1      -0.143772  0.635558  0.463917 -0.114805 -0.183361 -0.145783 -0.069083
# 2      -0.165946  2.345865 -2.890083  1.109969 -0.121359 -2.261857  0.524980
# 3      -0.287924 -0.631418 -1.059647 -0.684093  1.965775 -1.232622 -0.208038
# 4      -1.119670  0.175121 -0.451449 -0.237033 -0.038195  0.803487  0.408542
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  4.626942 -0.924459  1.107641  1.991691  0.510632 -0.682920  1.475829
# 284803 -0.675143  1.164931 -0.711757 -0.025693 -1.221179 -1.545556  0.059616
# 284804 -0.510602  1.329284  0.140716  0.313502  0.395652 -0.577252  0.001396
# 284805  0.449624  1.962563 -0.608577  0.509928  1.113981  2.897849  0.127434
# 284806 -0.084316  0.041333 -0.302620 -0.660377  0.167430 -0.256117  0.382948
#
#              V21       V22       V23       V24       V25       V26       V27  \
# 0      -0.018307  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558
# 1      -0.225775 -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983
# 2       0.247998  0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353
# 3      -0.108300  0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723
# 4      -0.009431  0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  0.213454  0.111864  1.014480 -0.509348  1.436807  0.250034  0.943651
# 284803  0.214205  0.924384  0.012463 -1.016226 -0.606624 -0.395255  0.068472
# 284804  0.232045  0.578229 -0.037501  0.640134  0.265745 -0.087371  0.004455
# 284805  0.265245  0.800049 -0.163298  0.123205 -0.569159  0.546668  0.108821
# 284806  0.261057  0.643078  0.376777  0.008797 -0.473649 -0.818267 -0.002415
#
#              V28    Amount  Class
# 0      -0.021053  0.244964      0
# 1       0.014724 -0.342475      0
# 2      -0.059752  1.160686      0
# 3       0.061458  0.140534      0
# 4       0.215153 -0.073403      0
# ...          ...       ...    ...
# 284802  0.823731 -0.350151      0
# 284803 -0.053527 -0.254117      0
# 284804 -0.026561 -0.081839      0
# 284805  0.104533 -0.313249      0
# 284806  0.013649  0.514355      0
#
# [284807 rows x 30 columns]

# %%
data.shape
# Out:
# (284807, 30)

# %%
#to check if any duplicates
data.duplicated().any()
# Out:
# True

# %%
data=data.drop_duplicates()

# %%
data.shape
# Out:
# (275663, 30)

# %%
#below number of duplicates are dropprd
284807-275663
# Out:
# 9144

# %% [markdown]
# # not handling imbalanced

# %%
data["Class"].value_counts()
# Out:
# 0    275190
# 1       473
# Name: Class, dtype: int64

# %%
sns.countplot(data["Class"])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
corrmat=data.corr()
corrmat
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# V1      1.000000  0.009002  0.005952 -0.000042 -0.018593 -0.005789 -0.006843
# V2      0.009002  1.000000  0.004976 -0.004095  0.004655  0.004290  0.004866
# V3      0.005952  0.004976  1.000000 -0.000721  0.011020  0.014780 -0.014016
# V4     -0.000042 -0.004095 -0.000721  1.000000  0.006710  0.012535  0.000806
# V5     -0.018593  0.004655  0.011020  0.006710  1.000000 -0.029701 -0.009107
# V6     -0.005789  0.004290  0.014780  0.012535 -0.029701  1.000000  0.013087
# V7     -0.006843  0.004866 -0.014016  0.000806 -0.009107  0.013087  1.000000
# V8     -0.000490  0.003743  0.003733  0.004996 -0.002605 -0.012301 -0.000987
# V9     -0.007093  0.001116 -0.002896  0.001395 -0.000786 -0.002290 -0.001657
# V10     0.003115  0.002764 -0.011064  0.003366 -0.002818 -0.002723 -0.012246
# V11    -0.005238 -0.001808  0.003763 -0.004402 -0.002965  0.000446  0.001731
# V12    -0.005225  0.001480 -0.003365  0.000561 -0.000343  0.004288 -0.007378
# V13     0.000176  0.000461 -0.000753  0.000332  0.001201 -0.000140  0.001019
# V14    -0.000167  0.004772 -0.008208  0.005336  0.005175  0.000178 -0.002006
# V15    -0.008538  0.001176  0.003324  0.004045 -0.007122 -0.009363  0.002165
# V16    -0.006376  0.002648  0.000336  0.001783 -0.004147 -0.002538 -0.003553
# V17    -0.001709  0.001304 -0.002813  0.001633 -0.005422  0.001747 -0.009985
# V18    -0.000037  0.000363 -0.003876  0.001569 -0.003108  0.000734 -0.004092
# V19    -0.000366  0.001164 -0.000828  0.005018  0.000351  0.000880  0.000590
# V20     0.003109 -0.000339 -0.004587  0.001165 -0.000788 -0.001835 -0.002196
# V21     0.006004 -0.003881  0.001818 -0.000623  0.003439 -0.001584  0.008635
# V22     0.003634  0.002909 -0.004203  0.001581  0.002971  0.002355 -0.001701
# V23    -0.007504 -0.003689  0.002183 -0.000155 -0.001058 -0.000221  0.003458
# V24    -0.009327  0.001974  0.009782  0.005759 -0.012634 -0.021098  0.005375
# V25    -0.004446 -0.002837  0.004091  0.000173 -0.004862 -0.006673  0.002070
# V26    -0.002436 -0.000296  0.003596 -0.001105 -0.001568  0.000702 -0.000459
# V27    -0.014628  0.007252 -0.008780  0.002517 -0.006116 -0.001577 -0.003977
# V28    -0.003555  0.001458 -0.002454  0.000028 -0.000711  0.000617  0.001329
# Amount -0.225854 -0.534153 -0.220547  0.100626 -0.390280  0.224967  0.401573
# V13     0.000214  0.000711 -0.001014 -0.000059  0.000887 -0.001451 -0.000380
# V14    -0.004795  0.000929  0.000332  0.002077  0.001404 -0.003828 -0.003178
# V15     0.002579  0.000727 -0.008461 -0.008245  0.001924 -0.001472  0.000156
# V16     0.003296  0.001524 -0.004437 -0.002464 -0.004495 -0.003528 -0.001855
# V17     0.000546  0.002412  0.004599 -0.003343 -0.001090 -0.003597 -0.003587
# V18    -0.004321  0.003488 -0.000836 -0.005231  0.003583 -0.005176 -0.001899
# V19     0.003521 -0.000357 -0.001410  0.000465  0.000907 -0.000011  0.000813
# V20    -0.002322  0.000748  0.000132 -0.000001 -0.000304 -0.000096  0.001828
# V21     0.001795 -0.004336  0.002943 -0.001299  0.000828 -0.005524 -0.004461
# V22     1.000000  0.006161  0.004008 -0.002331  0.004309  0.001686  0.001670
# V23     0.006161  1.000000 -0.001191  0.003625 -0.002105 -0.001520 -0.002719
# V24     0.004008 -0.001191  1.000000 -0.007007  0.001526 -0.001315  0.000086
# V25    -0.002331  0.003625 -0.007007  1.000000  0.004574 -0.001995 -0.001228
# V26     0.004309 -0.002105  0.001526  0.004574  1.000000 -0.000958 -0.000570
# V27     0.001686 -0.001520 -0.001315 -0.001995 -0.000958  1.000000 -0.014435
# V28     0.001670 -0.002719  0.000086 -0.001228 -0.000570 -0.014435  1.000000
# Amount -0.068382 -0.110847  0.009043 -0.045014 -0.003074  0.028293  0.009412
# Class   0.004612 -0.006206 -0.006831  0.003593  0.004341  0.021888  0.009642
#
#           Amount     Class
# V1     -0.225854 -0.094718
# V2     -0.534153  0.084754
# V3     -0.220547 -0.185772
# V4      0.100626  0.130313
# V5     -0.390280 -0.088642
# V6      0.224967 -0.044777
# V7      0.401573 -0.173292
# V8     -0.104572  0.033364
# V9     -0.041446 -0.094583
# V10    -0.104586 -0.208104
# V11     0.002091  0.151260
# V12    -0.007607 -0.253150
# V13     0.005123 -0.003934
# V14     0.033940 -0.297550
# V15     0.000946 -0.002824
# V16    -0.002611 -0.188222
# V17     0.007075 -0.317202
# V18     0.036231 -0.106447
# V19    -0.056118  0.033784
# V20     0.338585  0.021349
# V21     0.106363  0.026239
# V22    -0.068382  0.004612
# V23    -0.110847 -0.006206
# V24     0.009043 -0.006831
# V25    -0.045014  0.003593
# V26    -0.003074  0.004341
# V27     0.028293  0.021888
# V28     0.009412  0.009642
# Amount  1.000000  0.005451
# Class   0.005451  1.000000

# %%
import matplotlib.pyplot as plt

# %%
corrmat = data.corr()
fig = plt.figure(figsize = (12, 9))
sns.heatmap(corrmat, vmax = .8, square = True)
plt.show()

# %% [markdown]
# # storing feature matrix in X and terget variable in Y

# %%
#X=data.drop("Class",axis=1)
#y=data["Class"]

# %% [markdown]
# # splitting data into train and test dataset

# %%
#from sklearn.model_selection import train_test_split
#X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %% [markdown]
# # Handling imbalanced dataset

# %%
#undersampling
#oversampling

# %% [markdown]
# #undersampling

# %%
normal=data[data["Class"]==0]
fraud=data[data["Class"]==1]

# %%
normal.shape
# Out:
# (275190, 30)

# %%
fraud.shape
# Out:
# (473, 30)

# %%
normal_sample=normal.sample(n=473)

# %%
normal_sample.shape
# Out:
# (473, 30)

# %%
new_data=pd.concat([normal_sample,fraud],ignore_index=True)

# %%
new_data["Class"].value_counts()
# Out:
# 0    473
# 1    473
# Name: Class, dtype: int64

# %%
new_data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.267366  0.033036  3.057515 -0.388619 -0.492748 -0.270147  0.246332
# 1 -0.221076  0.622814  2.008656  0.695715 -0.269349 -0.576362  0.616767
# 2 -1.286013  0.478869  0.286722 -0.080205  0.520530  4.905002  0.361814
# 3 -0.204871  1.136555  0.173129 -0.353954  1.135805 -0.658703  1.088071
# 4  1.331805 -2.201186 -3.097482 -0.604276 -0.367729 -1.330648  0.884882
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.087358  0.258467 -0.579799  0.213005  0.124102  0.244217 -0.575111
# 1 -0.239736  0.145053 -0.245767 -0.619637 -0.139157 -0.692389 -0.315268
# 2  1.355807 -0.384963 -0.806950 -0.619168 -0.124115  0.127370  0.100095
# 3 -0.189357 -0.597564 -1.078104 -0.578547  0.152101  0.780468 -1.049652
# 4 -0.549515 -0.991072  0.954885  0.301893 -1.333737 -2.427491  1.200665
#
#         V15       V16       V17       V18       V19       V20       V21  \
# 0  1.288781  0.449956 -0.532912 -0.143574 -1.653558  0.411853  0.315302
# 1 -0.213996 -0.897077  0.390083 -0.369347  0.894231  0.044693 -0.010826
# 2  1.057237  0.446003 -0.486695  0.852945  0.876552  0.091763  0.032116
# 3 -0.012955  0.037646  0.551830 -0.188994  0.448018  0.056984 -0.262162
# 4 -0.898315  0.519754  0.339100 -0.777027  1.018898  0.787264  0.776983
#
#         V22       V23       V24       V25       V26       V27       V28  \
# 0  0.940205 -0.004090  0.653024  0.146327  0.479577  0.085794 -0.073264
# 1  0.368450 -0.195933  0.763727 -0.288461  0.414197 -0.042734 -0.085078
# 2 -0.030595  0.041034  1.007253  0.456824 -0.252900 -0.002215 -0.059001
# 3 -0.687657 -0.057038  0.598820 -0.413392  0.208127  0.102802  0.183238
# 4  1.075752 -0.682789 -0.272050  0.517817  0.256321 -0.207344 -0.026492
#
#      Amount  Class
# 0  0.023990      0
# 1 -0.338077      0
# 2  0.827805      0
# 3 -0.349271      0
# 4  1.645814      0

# %%
X=new_data.drop("Class",axis=1)
y=new_data["Class"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
log=LogisticRegression()
log.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred1=log.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.9315789473684211

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.9315789473684211

# %%
from sklearn.metrics import precision_score,recall_score,f1_score

# %%
precision_score(y_test,y_pred1)
# Out:
# 0.9494949494949495

# %%
precision_score(y_test,y_pred1)
# Out:
# 0.9494949494949495

# %%
recall_score(y_test,y_pred1)
# Out:
# 0.9215686274509803

# %%
recall_score(y_test,y_pred1)
# Out:
# 0.9215686274509803

# %%
f1_score(y_test,y_pred1)
# Out:
# 0.9353233830845771

# %%
f1_score(y_test,y_pred1)
# Out:
# 0.9353233830845771

# %% [markdown]
# # Decision tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2=dt.predict(X_test)

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.8789473684210526

# %%
precision_score(y_test,y_pred2)
# Out:
# 0.898989898989899

# %%
recall_score(y_test,y_pred2)
# Out:
# 0.8725490196078431

# %%
f1_score(y_test,y_pred2)
# Out:
# 0.8855721393034826

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred3=rf.predict(X_test)

# %%
accuracy_score(y_test,y_pred3)
# Out:
# 0.9315789473684211

# %%
precision_score(y_test,y_pred3)
# Out:
# 0.9587628865979382

# %%
recall_score(y_test,y_pred3)
# Out:
# 0.9117647058823529

# %%
f1_score(y_test,y_pred3)
# Out:
# 0.9346733668341709

# %%
final_data=pd.DataFrame({"Models":["LR","DT","RF"],"ACC":[accuracy_score(y_test,y_pred1)*100,
                                              accuracy_score(y_test,y_pred2)*100,
                                              accuracy_score(y_test,y_pred3)*100]})

# %%
final_data
# Out:
#   Models        ACC
# 0     LR  93.157895
# 1     DT  87.894737
# 2     RF  93.157895

# %%
sns.barplot(final_data["Models"],final_data["ACC"])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Models', ylabel='ACC'>

# %% [markdown]
# #Oversampling

# %%
X=data.drop("Class",axis=1)
y=data["Class"]

# %%
X.shape
# Out:
# (275663, 29)

# %%
y.shape
# Out:
# (275663,)

# %%
from imblearn.over_sampling import SMOTE

# %%
X_res,y_res=SMOTE().fit_resample(X,y)

# %%
y_res.value_counts()
# Out:
# 0    275190
# 1    275190
# Name: Class, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_res,y_res,test_size=0.20,random_state=42)

# %% [markdown]
# # Logistic REgression

# %%
log=LogisticRegression()
log.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred1=log.predict(X_test)

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.9454013590610124

# %%
precision_score(y_test,y_pred1)
# Out:
# 0.9729510570518389

# %%
recall_score(y_test,y_pred1)
# Out:
# 0.9162045706597822

# %%
f1_score(y_test,y_pred1)
# Out:
# 0.943725537931422

# %% [markdown]
# # DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2=dt.predict(X_test)

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.9980468040263091

# %%
precision_score(y_test,y_pred2)
# Out:
# 0.9971146517620586

# %%
recall_score(y_test,y_pred2)
# Out:
# 0.9989818737159791

# %%
f1_score(y_test,y_pred2)
# Out:
# 0.9980473894050441

# %% [markdown]
# # RandomForestClassifer

# %%
rf=RandomForestClassifier()

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred3=rf.predict(X_test)

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.9980468040263091

# %%
precision_score(y_test,y_pred2)
# Out:
# 0.9971146517620586

# %%
recall_score(y_test,y_pred2)
# Out:
# 0.9989818737159791

# %%
f1_score(y_test,y_pred2)
# Out:
# 0.9980473894050441

# %%
final_data=pd.DataFrame({"Models":["LR","DT","RF"],"ACC":[accuracy_score(y_test,y_pred1)*100,
                                              accuracy_score(y_test,y_pred2)*100,
                                              accuracy_score(y_test,y_pred3)*100]})

# %%
final_data
# Out:
#   Models        ACC
# 0     LR  94.540136
# 1     DT  99.804680
# 2     RF  99.992732

# %%
sns.barplot(final_data["Models"],final_data["ACC"])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Models', ylabel='ACC'>

# %% [markdown]
# # Save the model

# %%
rf1=RandomForestClassifier()

# %%
rf1.fit(X_res,y_res)
# Out:
# RandomForestClassifier()

# %%
import joblib

# %%
joblib.dump(rf1,"credit_card_model")
# Out:
# ['credit_card_model']

# %%
model=joblib.load("credit_card_model")

# %%
pred=model.predict([[1,1,1,1,1,1,1,1,90890,1,1,1,1,1,1,1,1,1,89,1,1,1,1,1,1,1,1,9098,1]])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
if pred==0:
    print("Normal Transaction")
else:
    print("Fraudulent Transaction")
# Out:
# Normal Transaction
